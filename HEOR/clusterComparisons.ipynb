# %% [markdown]
# # Cluster comparison
# This will be accomplished in two steps:
#  1. statistical test across each variable comparing the sample populations across various measurements
#  2. identifying the mean values across each of these measurements.
#
# The result will be a report for each patient subgroup displaying its expected values for a particular measurement, the expected values for the same measurement for the rest of the patient population, the difference, and whether or not that difference is statistically significant.

# %%
import os
import re
import pandas as pd
import numpy as np

# Statistical tests
from scipy.stats import ttest_ind, chisquare, chi2_contingency

# user scripts
from dfGenUtils import convertCategorical, genPatientDF, dropMissings

# %%
input_dir = "../data/heorData/"
graph_dir = "../data/graphs/"
patient_dir = "../data/patientData/"
output_dir = "../data/heorData/results/"

# %% [markdown]
# ## Generate Dataframe and Metadata Variables
#   1. Need to compute descriptive stats and statistical tests before imputation of missing vars
#   2. Need to identify which columns belong to which data subgroups

# %%
cluster_df = pd.read_csv(graph_dir + "cosine_cluster5.csv")
cluster_df.head()
# Out:
#    subject_id  cluster
# 0           4        0
# 1       29573        0
# 2        4699        0
# 3       31535        0
# 4       57317        1

# %%
mortality = pd.read_csv(patient_dir + "mortality.csv")
mortality.head()
# Out:
#    subject_id last_admission  death_date  time2event  mortality30
# 0        7275     2140-04-12  2140-05-08        26.0            1
# 1         357     2199-12-21  2201-08-02       589.0            0
# 2         878     2137-11-24  2137-12-11        17.0            1
# 3         794     2190-11-29  2191-09-19       294.0            0
# 4        1457     2189-01-25         NaN         NaN            0

# %%
# generate our patient dataframe and drop missings. But, do not impute
files = os.listdir(patient_dir)
files = [f for f in files if re.search("chart events|cross sect", f)]

patient_df = genPatientDF(patient_dir, files, cluster_df, mortality, time2event = True)
patient_df = dropMissings(patient_df, .5)
patient_df.head()
# Out:
#    subject_id activity activity_tolerance     braden_activity  \
# 0           4  Bedrest     Tolerated Well  Walks Occasionally
# 1          52  Bedrest     Tolerated Well             Bedfast
# 2          78  Bedrest     Tolerated Well             Bedfast
# 3         117  Bedrest     Tolerated Well             Bedfast
# 4         140  Bedrest     Tolerated Well           Chairfast
#
#       braden_mobility family_communication marital_status  \
# 0  Slight Limitations       Family Visited         Single
# 1  Slight Limitations       Family Visited         Single
# 2      No Limitations       Family Visited              A
# 3        Very Limited       Family Visited         Single
# 4      No Limitations        Family Called       Divorced
#
#                       race gender     braden_nutrition  ...      avg_ld  \
# 0  Unknown / Not Specified      F  Probably Inadequate  ...  330.000000
# 1  Unknown / Not Specified      M  Probably Inadequate  ...  285.888889
# 2  Unknown / Not Specified      M             Adequate  ...         NaN
# 3  Unknown / Not Specified      F  Probably Inadequate  ...  577.473684
# 4  Unknown / Not Specified      M             Adequate  ...         NaN
#
#   min_lactate max_lactate avg_lactate avg_phosphate  avg_sodium avg_potassium  \
# 0         2.1         2.1     2.10000      3.450000  137.750000      3.537500
# 1         NaN         NaN         NaN      3.470000  134.916667      3.600000
# 2         NaN         NaN         NaN      3.166667  137.000000      3.580000
# 3         1.2        21.9     8.90625      4.576087  137.472727      4.426316
# 4         NaN         NaN         NaN      3.133333  137.666667      4.333333
#
#   cluster mortality30 time2event
# 0       0           0        NaN
# 1       0           0      548.0
# 2       0           0     1083.0
# 3       0           1       18.0
# 4       0           0      677.0
#
# [5 rows x 129 columns]

# %%
num_clusters = max(cluster_df.cluster) +1
clusters = range(num_clusters)
num_clusters
# Out:
# 2

# %%
# identify which columns belong to which data subgroups
# format is dictionary{column name: data_group}
def extractColumnGroupings(patient_dir):
    columnMapping = {}
    patient_files = os.listdir(patient_dir)
    
    for f in patient_files:
        curr_df = pd.read_csv(patient_dir + f)
        columns = curr_df.columns
        
        # extract data subgroup name 
        m = re.search("_.*_(.*?)\.", f)
        if m:
            data_subgroup = m.group(1)
            
            # chart event files have the column names in the label variable
            chart_event = re.search("chart events_categorical", f)
            if chart_event:
                columns = list(curr_df.label.unique())
                columns = ['_'.join(c for c in col.lower().split()) for col in columns]
                
            [columnMapping.update({col:data_subgroup}) for col in columns]
            
    # manually add mortality
    columnMapping['mortality30'] = 'mortality'
    columnMapping['time2event'] = 'mortality'
    
    return columnMapping

columnMapping = extractColumnGroupings(patient_dir)
columnMapping
# Out:
# {'activity': 'activity',
#  'activity_tolerance': 'activity',
#  'braden_activity': 'activity',
#  'braden_mobility': 'activity',
#  'family_communication': 'demographics',
#  'marital_status': 'demographics',
#  'gender': 'demographics',
#  'race': 'demographics',
#  'braden_nutrition': 'diet',
#  'diet_type': 'diet',
#  'appetite': 'diet',
#  'special_diet': 'diet',
#  'heart_rhythm': 'heart lung',
#  'lll_lung_sounds': 'heart lung',
#  'lul_lung_sounds': 'heart lung',
#  'rll_lung_sounds': 'heart lung',
#  'rul_lung_sounds': 'heart lung',
#  'respiratory_pattern': 'heart lung',
#  'respiratory_effort': 'heart lung',
#  'mental_status': 'mental drug',
#  'recreational_drug_use': 'mental drug',
#  'pain_location': 'pain',
#  'pain_present': 'pain',
#  'pain_cause': 'pain',
#  'pain_type': 'pain',
#  'abdominal_assessment': 'physical assessment',
#  'bowel_sounds': 'physical assessment',
#  'braden_moisture': 'physical assessment',
#  'oral_cavity': 'physical assessment',
#  'skin_color': 'physical assessment',
#  'skin_condition': 'physical assessment',
#  'cough_reflex': 'physical assessment',
#  'gag_reflex': 'physical assessment',
#  'speech': 'physical assessment',
#  'subject_id': 'procedures',
#  'age': 'demographics',
#  'max_heart_rate': 'heart lung rate',
#  'min_heart_rate': 'heart lung rate',
#  'avg_heart_rate': 'heart lung rate',
#  'max_resp_rate': 'heart lung rate',
#  'min_resp_rate': 'heart lung rate',
#  'avg_resp_rate': 'heart lung rate',
#  'anemia': 'medical history',
#  'angina': 'medical history',
#  'arrhythmias': 'medical history',
#  'asthma': 'medical history',
#  'cad': 'medical history',
#  'chf': 'medical history',
#  'copd': 'medical history',
#  'cva': 'medical history',
#  'diabetes_-_insulin': 'medical history',
#  'diabetes_-_oral_agent': 'medical history',
#  'etoh': 'medical history',
#  'gi_bleed': 'medical history',
#  'hemo_or_pd': 'medical history',
#  'hepatitis': 'medical history',
#  'hypertension': 'medical history',
#  'liver_failure': 'medical history',
#  'mi': 'medical history',
#  'pvd': 'medical history',
#  'pacemaker': 'medical history',
#  'pancreatitis': 'medical history',
#  'renal_failure': 'medical history',
#  'seizures': 'medical history',
#  'smoker': 'medical history',
#  'Abdominal': 'pain level',
#  'Back': 'pain level',
#  'Both Legs': 'pain level',
#  'Chest Pain': 'pain level',
#  'Generalized': 'pain level',
#  'Headache': 'pain level',
#  'Incisional': 'pain level',
#  'Jaw': 'pain level',
#  'Left Arm': 'pain level',
#  'Left Chest': 'pain level',
#  'Left Elbow': 'pain level',
#  'Left Flank': 'pain level',
#  'Left Foot': 'pain level',
#  'Left Hip': 'pain level',
#  'Left Leg': 'pain level',
#  'Left Lower Quad': 'pain level',
#  'Left Lower Quadrant': 'pain level',
#  'Left Shoulder': 'pain level',
#  'Left Upper Quad': 'pain level',
#  'Left Upper Quadrant': 'pain level',
#  'Mediastinal': 'pain level',
#  'Midscapular': 'pain level',
#  'Neck': 'pain level',
#  'Not Indicated': 'pain level',
#  'Perineum': 'pain level',
#  'Periumbilical': 'pain level',
#  'Right Arm': 'pain level',
#  'Right Chest': 'pain level',
#  'Right Elbow': 'pain level',
#  'Right Flank': 'pain level',
#  'Right Foot': 'pain level',
#  'Right Hip': 'pain level',
#  'Right Leg': 'pain level',
#  'Right Lower Quad': 'pain level',
#  'Right Lower Quadrant': 'pain level',
#  'Right Shoulder': 'pain level',
#  'Right Upper Quad': 'pain level',
#  'Right Upper Quadrant': 'pain level',
#  'max_wgt': 'weight',
#  'min_wgt': 'weight',
#  'wgt_change': 'weight',
#  'loss_perc': 'weight',
#  'anti_mitochondrial': 'antibodies',
#  'anti_nuclear_titer': 'antibodies',
#  'anti_nuclear': 'antibodies',
#  'anti_smooth_muscle': 'antibodies',
#  'min_fibrinogen': 'blood',
#  'max_fibrinogen': 'blood',
#  'avg_fibrinogen': 'blood',
#  'min_platelet': 'blood',
#  'max_platelet': 'blood',
#  'avg_platelet': 'blood',
#  'min_inr': 'blood',
#  'max_inr': 'blood',
#  'avg_inr': 'blood',
#  'min_pt': 'blood',
#  'max_pt': 'blood',
#  'avg_pt': 'blood',
#  'min_ptt': 'blood',
#  'max_ptt': 'blood',
#  'avg_ptt': 'blood',
#  'first_ferritin': 'blood',
#  'first_iron': 'blood',
#  'first_iron_bind': 'blood',
#  'first_transferrin': 'blood',
#  'last_ferritin': 'blood',
#  'last_iron': 'blood',
#  'last_iron_bind': 'blood',
#  'last_transferrin': 'blood',
#  'min_albumin': 'breakdown products',
#  'max_albumin': 'breakdown products',
#  'avg_albumin': 'breakdown products',
#  'avg_alb_ascites': 'breakdown products',
#  'min_bilirubin': 'breakdown products',
#  'max_bilirubin': 'breakdown products',
#  'avg_bilirubin': 'breakdown products',
#  'avg_bili_ascites': 'breakdown products',
#  'avg_bili_direct': 'breakdown products',
#  'avg_bili_indirect': 'breakdown products',
#  'min_creatinine': 'breakdown products',
#  'max_creatinine': 'breakdown products',
#  'avg_creatinine': 'breakdown products',
#  'avg_ck': 'breakdown products',
#  'avg_ck_iso': 'breakdown products',
#  'avg_creat_urine': 'breakdown products',
#  'min_alt': 'enzymes',
#  'max_alt': 'enzymes',
#  'avg_alt': 'enzymes',
#  'min_ast': 'enzymes',
#  'max_ast': 'enzymes',
#  'avg_ast': 'enzymes',
#  'min_alkph': 'enzymes',
#  'max_alkph': 'enzymes',
#  'avg_alkph': 'enzymes',
#  'min_ld': 'enzymes',
#  'max_ld': 'enzymes',
#  'avg_ld': 'enzymes',
#  'min_ld_ascites': 'enzymes',
#  'max_ld_ascites': 'enzymes',
#  'avg_ld_ascites': 'enzymes',
#  'min_lactate': 'enzymes',
#  'max_lactate': 'enzymes',
#  'avg_lactate': 'enzymes',
#  'hep_b_surf_antibody': 'hepatitis',
#  'hep_b_surf_antigen': 'hepatitis',
#  'hep_c_antibody': 'hepatitis',
#  'hep_b_virus_antibody': 'hepatitis',
#  'avg_phosphate': 'other lab',
#  'avg_gamma_glut': 'other lab',
#  'avg_amonia': 'other lab',
#  'avg_acetamin': 'other lab',
#  'avg_sodium': 'other lab',
#  'avg_potassium': 'other lab',
#  'min_protein': 'proteins',
#  'max_protein': 'proteins',
#  'avg_protein': 'proteins',
#  'avg_tot_protein': 'proteins',
#  'avg_urine_prot': 'proteins',
#  'avg_ascite_prot': 'proteins',
#  'avg_fetoprotein': 'proteins',
#  'label': 'procedures',
#  'value': 'procedures',
#  'frequency': 'procedures',
#  'mortality30': 'mortality',
#  'time2event': 'mortality'}

# %%
# define our variable groups - maybe I subset to top 50 most important columns? 
# I will need to extract the groupings 
num_vars = patient_df.select_dtypes(include=np.number).columns.tolist()
num_vars = [c for c in num_vars if c not in ["subject_id", "cluster"]]

cat_vars = patient_df.select_dtypes(include=["object"]).columns.tolist()
num_vars, cat_vars
# Out:
# (['age',
#   'max_heart_rate',
#   'min_heart_rate',
#   'avg_heart_rate',
#   'max_resp_rate',
#   'min_resp_rate',
#   'avg_resp_rate',
#   'Abdominal',
#   'Back',
#   'Both Legs',
#   'Chest Pain',
#   'Generalized',
#   'Headache',
#   'Incisional',
#   'Jaw',
#   'Left Arm',
#   'Left Chest',
#   'Left Elbow',
#   'Left Flank',
#   'Left Foot',
#   'Left Hip',
#   'Left Leg',
#   'Left Lower Quad',
#   'Left Lower Quadrant',
#   'Left Shoulder',
#   'Left Upper Quad',
#   'Left Upper Quadrant',
#   'Mediastinal',
#   'Midscapular',
#   'Neck',
#   'Not Indicated',
#   'Perineum',
#   'Periumbilical',
#   'Right Arm',
#   'Right Chest',
#   'Right Elbow',
#   'Right Flank',
#   'Right Foot',
#   'Right Hip',
#   'Right Leg',
#   'Right Lower Quad',
#   'Right Lower Quadrant',
#   'Right Shoulder',
#   'Right Upper Quad',
#   'Right Upper Quadrant',
#   'max_wgt',
#   'min_wgt',
#   'wgt_change',
#   'loss_perc',
#   'min_fibrinogen',
#   'max_fibrinogen',
#   'avg_fibrinogen',
#   'min_platelet',
#   'max_platelet',
#   'avg_platelet',
#   'min_inr',
#   'max_inr',
#   'avg_inr',
#   'min_pt',
#   'max_pt',
#   'avg_pt',
#   'min_ptt',
#   'max_ptt',
#   'avg_ptt',
#   'min_albumin',
#   'max_albumin',
#   'avg_albumin',
#   'min_bilirubin',
#   'max_bilirubin',
#   'avg_bilirubin',
#   'min_creatinine',
#   'max_creatinine',
#   'avg_creatinine',
#   'avg_ck',
#   'avg_creat_urine',
#   'min_alt',
#   'max_alt',
#   'avg_alt',
#   'min_ast',
#   'max_ast',
#   'avg_ast',
#   'min_alkph',
#   'max_alkph',
#   'avg_alkph',
#   'min_ld',
#   'max_ld',
#   'avg_ld',
#   'min_lactate',
#   'max_lactate',
#   'avg_lactate',
#   'avg_phosphate',
#   'avg_sodium',
#   'avg_potassium',
#   'mortality30',
#   'time2event'],
#  ['activity',
#   'activity_tolerance',
#   'braden_activity',
#   'braden_mobility',
#   'family_communication',
#   'marital_status',
#   'race',
#   'gender',
#   'braden_nutrition',
#   'diet_type',
#   'heart_rhythm',
#   'lll_lung_sounds',
#   'lul_lung_sounds',
#   'rll_lung_sounds',
#   'rul_lung_sounds',
#   'respiratory_effort',
#   'respiratory_pattern',
#   'mental_status',
#   'recreational_drug_use',
#   'pain_cause',
#   'pain_location',
#   'pain_present',
#   'pain_type',
#   'abdominal_assessment',
#   'bowel_sounds',
#   'braden_moisture',
#   'cough_reflex',
#   'gag_reflex',
#   'oral_cavity',
#   'skin_color',
#   'skin_condition',
#   'speech'])

# %% [markdown]
# ## Statistical Tests
# I take a one vs. all approach here. For each cluster, I compare the samples from the selected cluster to all other data. I do this for each cluster.
#
# For numeric data, I compare the means using a t-test. For categorical data, I compare using the chi-squared test.

# %%
# run ttests for all numeric variables for a given cluster
def tTests(cols, patient_df, cluster):
    test_res = []
    for col in cols:
        main = patient_df.loc[patient_df.cluster == cluster, col].dropna()
        other = patient_df.loc[patient_df.cluster != cluster, col].dropna()

        # run tests and append
        res = ttest_ind(main, other)
        sum_stats_main = {"mean":round(main.mean(),2),
                          "std":round(main.std(),2)}
        sum_stats_other = {"mean":round(other.mean(),2),
                           "std":round(other.std(),2)}
        
        test_res.append([col, # column
                         sum_stats_main,# numeric summary stats for comparison cluster                         
                         sum_stats_other, # numeric summary stats for all others
                         round(res.pvalue,4)]) # p value
    return test_res 

numeric_res = tTests(num_vars, patient_df, c)
numeric_res[:5]
# Out:
# [['age', {'mean': 59.65, 'std': 27.78}, {'mean': 58.78, 'std': 26.41}, 0.3892],
#  ['max_heart_rate',
#   {'mean': 7082.3, 'std': 263886.75},
#   {'mean': 120.93, 'std': 24.87},
#   0.3187],
#  ['min_heart_rate',
#   {'mean': 63.21, 'std': 16.07},
#   {'mean': 60.17, 'std': 15.65},
#   0.0],
#  ['avg_heart_rate',
#   {'mean': 96.72, 'std': 379.23},
#   {'mean': 86.21, 'std': 13.04},
#   0.295],
#  ['max_resp_rate',
#   {'mean': 38.62, 'std': 125.32},
#   {'mean': 34.45, 'std': 13.03},
#   0.2112]]

# %%
# extract the top three most frequent categorical values and their percent frequency
def mostFrequentCats(frequencies, n = 3):
    top_cats = {}
    total_obs = frequencies.sum()
    freq_ratio = frequencies/total_obs
    [top_cats.update({row[0]: round(row[1],2)}) for i, row in enumerate(freq_ratio.iteritems()) if i < n]
    return top_cats

# %%
# run our chisquared tests for all categorical variables leveraging contingency tables for a given cluster
def chi2Tests(cols, patient_df, cluster):
    test_res = []
    for col in cols:
        # generate our contingency table
        main = patient_df.loc[patient_df.cluster == cluster, col].value_counts()
        other = patient_df.loc[patient_df.cluster != cluster, col].value_counts()
        contingency_tbl = pd.merge(main, other, how = 'left', left_index = True, right_index = True).fillna(0)
        
        # run tests and append
        chi2, p, ddof, expected = chi2_contingency(contingency_tbl)
        test_res.append([col, # column
                         mostFrequentCats(main,3), # top 3 cat labels and their frequencies
                         mostFrequentCats(other,3), # top 3 labels for the other group
                         round(p, 4)]) # p value
    return test_res

cat_res = chi2Tests(cat_vars, patient_df, c)
cat_res[:5]
# Out:
# [['activity',
#   {'Bedrest': 0.98, 'Commode': 0.01, 'Chair': 0.01},
#   {'Bedrest': 0.99, 'Chair': 0.0, 'Commode': 0.0},
#   0.3743],
#  ['activity_tolerance',
#   {'Tolerated Well': 0.8, 'Good': 0.18, 'Fair': 0.02},
#   {'Tolerated Well': 0.93, 'Good': 0.04, 'Fair': 0.02},
#   0.0],
#  ['braden_activity',
#   {'Bedfast': 0.89, 'Chairfast': 0.05, 'Walks Occasionally': 0.05},
#   {'Bedfast': 0.92, 'Chairfast': 0.04, 'Walks Occasionally': 0.04},
#   0.224],
#  ['braden_mobility',
#   {'Slight Limitations': 0.56, 'Very Limited': 0.32, 'No Limitations': 0.07},
#   {'Slight Limitations': 0.49,
#    'Very Limited': 0.38,
#    'Completely Immobile': 0.07},
#   0.0004],
#  ['family_communication',
#   {'Family Visited': 0.5, 'Family Talked to RN': 0.26, 'Family Called': 0.18},
#   {'Family Visited': 0.66, 'Family Called': 0.27, 'Family Talked to MD': 0.03},
#   0.0]]

# %% [markdown]
# ## Generate the Report

# %%
def genReport(num_res, cat_res, columnMapping, cluster):
    # gen base report
    num_df = pd.DataFrame(num_res)
    cat_df = pd.DataFrame(cat_res)
    report = pd.concat([num_df, cat_df], axis = 0)
    report.columns = ['variable', 'main_summary_stats', 'other_summary_stats', 'p_value']
    report['cluster'] = cluster
    
    # extract the data subgroups
    report['data_subgroup'] = report.variable.map(columnMapping)
    
    return report.reset_index(drop = True)

report = genReport(numeric_res, cat_res, columnMapping, c)
report.head()
# Out:
#          variable                  main_summary_stats  \
# 0             age       {'mean': 59.65, 'std': 27.78}
# 1  max_heart_rate  {'mean': 7082.3, 'std': 263886.75}
# 2  min_heart_rate       {'mean': 63.21, 'std': 16.07}
# 3  avg_heart_rate      {'mean': 96.72, 'std': 379.23}
# 4   max_resp_rate      {'mean': 38.62, 'std': 125.32}
#
#               other_summary_stats  p_value  cluster    data_subgroup
# 0   {'mean': 58.78, 'std': 26.41}   0.3892        1     demographics
# 1  {'mean': 120.93, 'std': 24.87}   0.3187        1  heart lung rate
# 2   {'mean': 60.17, 'std': 15.65}   0.0000        1  heart lung rate
# 3   {'mean': 86.21, 'std': 13.04}   0.2950        1  heart lung rate
# 4   {'mean': 34.45, 'std': 13.03}   0.2112        1  heart lung rate

# %%
# run through the process for both clusters and then concatenate
cluster_report_list = []
for c in range(num_clusters):
    # run tests
    num_res = tTests(num_vars, patient_df, c)
    cat_res = chi2Tests(cat_vars, patient_df, c)
    
    # gen report
    report = genReport(num_res, cat_res, columnMapping, c)
    cluster_report_list.append(report)
    
# concatenate
cluster_reports = pd.concat(cluster_report_list, axis = 0)
cluster_reports
# Out:
#            variable                                 main_summary_stats  \
# 0               age                      {'mean': 58.78, 'std': 26.41}
# 1    max_heart_rate                     {'mean': 120.93, 'std': 24.87}
# 2    min_heart_rate                      {'mean': 60.17, 'std': 15.65}
# 3    avg_heart_rate                      {'mean': 86.21, 'std': 13.04}
# 4     max_resp_rate                      {'mean': 34.45, 'std': 13.03}
# ..              ...                                                ...
# 122      gag_reflex  {'Intact': 0.76, 'Impaired': 0.19, 'Absent': 0...
# 123     oral_cavity  {'Teeth/Tissue WNL': 0.91, 'Bleeding Gum': 0.0...
# 124      skin_color  {'Normal for Race': 0.75, 'Jaundiced': 0.19, '...
# 125  skin_condition     {'Dry ': 0.99, 'Dry': 0.0, 'Diaphoretic': 0.0}
# 126          speech  {'Normal': 0.68, 'Intubated/trached': 0.27, 'G...
#
#                                    other_summary_stats  p_value  cluster  \
# 0                        {'mean': 59.65, 'std': 27.78}   0.3892        0
# 1                   {'mean': 7082.3, 'std': 263886.75}   0.3187        0
# 2                        {'mean': 63.21, 'std': 16.07}   0.0000        0
# 3                       {'mean': 96.72, 'std': 379.23}   0.2950        0
# 4                       {'mean': 38.62, 'std': 125.32}   0.2112        0
# ..                                                 ...      ...      ...
# 122  {'Intact': 0.68, 'Impaired': 0.23, 'Absent': 0...   0.0003        1
# 123  {'Teeth/Tissue WNL': 0.94, 'Bleeding Gum': 0.0...   0.0001        1
# 124  {'Normal for Race': 0.59, 'Jaundiced': 0.31, '...   0.0000        1
# 125        {'Dry': 0.66, 'Dry ': 0.33, 'Clammy': 0.01}   0.0000        1
# 126  {'Normal': 0.55, 'Intubated/trached': 0.32, 'G...   0.0000        1
#
#            data_subgroup
# 0           demographics
# 1        heart lung rate
# 2        heart lung rate
# 3        heart lung rate
# 4        heart lung rate
# ..                   ...
# 122  physical assessment
# 123  physical assessment
# 124  physical assessment
# 125  physical assessment
# 126  physical assessment
#
# [254 rows x 6 columns]

# %%
cluster_reports.to_csv(output_dir + "Cluster Reports (cosine_knn5_k2).csv")
