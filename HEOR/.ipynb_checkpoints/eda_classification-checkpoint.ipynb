# %% [markdown]
# # 30 Day Mortality Prediction - Single Model
# Evaluate using a single model for the entire dataset

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import pandas as pd
import numpy as np
import re

# ML
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, roc_auc_score, f1_score
import shap

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# user functions
from dfGenUtils import convertCategorical, genPatientDF, dropMissings, imputeMissings

# %%
input_dir = "../data/heorData/"
graph_dir = "../data/graphs/"
patient_dir = "../data/patientData/"
output_dir = input_dir + "results/"

num_clusters = 2

# %%
cluster_df = pd.read_csv(graph_dir + "cosine_cluster5.csv")
cluster_df.head()
# Out:
#    subject_id  cluster
# 0           4        0
# 1         314        0
# 2         761        0
# 3        1152        0
# 4        3064        0

# %%
mortality = pd.read_csv(patient_dir + "mortality.csv")
mortality.head()
# Out:
#    subject_id last_admission  death_date  time2event  mortality30
# 0        7275     2140-04-12  2140-05-08        26.0            1
# 1         357     2199-12-21  2201-08-02       589.0            0
# 2         878     2137-11-24  2137-12-11        17.0            1
# 3         794     2190-11-29  2191-09-19       294.0            0
# 4        1457     2189-01-25         NaN         NaN            0

# %%
files = os.listdir(patient_dir)
files = [f for f in files if re.search("chart events|cross sect", f)]

patient_df = genPatientDF(patient_dir, files, cluster_df, mortality, time2event = True)
patient_df.head()
# Out:
#    subject_id activity activity_tolerance     braden_activity  \
# 0           4  Bedrest     Tolerated Well  Walks Occasionally
# 1          52  Bedrest     Tolerated Well             Bedfast
# 2          78  Bedrest     Tolerated Well             Bedfast
# 3         117  Bedrest     Tolerated Well             Bedfast
# 4         140  Bedrest     Tolerated Well           Chairfast
#
#       braden_mobility family_communication marital_status race gender  \
# 0  Slight Limitations       Family Visited         Single  NaN      F
# 1  Slight Limitations       Family Visited         Single  NaN      M
# 2      No Limitations       Family Visited              A  NaN      M
# 3        Very Limited       Family Visited         Single  NaN      F
# 4      No Limitations        Family Called       Divorced  NaN      M
#
#   appetite  ... min_protein max_protein avg_protein avg_tot_protein  \
# 0      NaN  ...        30.0        30.0        30.0             NaN
# ...

# %%
cat_vars = ["activity", "activity_tolerance", "braden_activity", "braden_mobility", 
            "family_communication", "marital_status", "race", "gender", "braden_nutrition", 
            "diet_type", "heart_rhythm", "lll_lung_sounds", "lul_lung_sounds", "rll_lung_sounds", 
            "rul_lung_sounds", "respiratory_effort", "respiratory_pattern", "mental_status", 
            "pain_cause", "pain_location", "pain_present", "pain_type", "abdominal_assessment", 
            "bowel_sounds", "braden_moisture", "cough_reflex", "gag_reflex", "oral_cavity", 
            "skin_color", "skin_condition", "speech", "appetite"]

# convert to pandas categorical
def convertCat(df, cat_vars):
    cat_vars_tmp = [c for c in cat_vars if c in df.columns]
    for col in cat_vars_tmp:
        df[col] = df[col].astype('category')
    return df

# %%
# clean
patient_df = pd.read_csv("../shiny/data/Patient Level Dataset.csv")
missing_percent = .5
patient_df = dropMissings(patient_df, missing_percent)
patient_df = imputeMissings(patient_df)
patient_df = convertCat(patient_df, cat_vars)
patient_df.recreational_drug_use = patient_df.recreational_drug_use.astype("float") 
patient_df
# Out:
#       subject_id  recreational_drug_use   age  max_heart_rate  min_heart_rate  \
# 0            4.0                    0.0  48.0           111.0            74.0
# 1           52.0                    0.0  39.0           106.0            85.0
# 2           78.0                    0.0  49.0            86.0            56.0
# 3          117.0                    0.0  50.0           219.0            56.0
# 4          140.0                    0.0  53.0           117.0            65.0
# ...          ...                    ...   ...             ...             ...
# 2864     99791.0                    0.0  61.0           122.0            69.0
# 2865     99830.0                    0.0  49.0           164.0            65.0
# 2866     99836.0                    0.0  52.0           131.0            70.0
# 2867     99862.0                    0.0  59.0           127.0            77.0
# 2868     99923.0                    0.0  55.0           148.0            77.0
#
# ...

# %%
# run the classifier
def fitClf(X_train, y_train, X_test, y_test, metric = "auc"):
    # define our parameters
    fit_params={"early_stopping_rounds":10, 
            "eval_metric" : metric, 
            "eval_set" : [(X_test,y_test)],
            'eval_names': ['valid'],
            'verbose': 100,
            'feature_name': 'auto', # default
            'categorical_feature': 'auto' # default
           }

    # generate clf 
    clf = lgb.LGBMClassifier(is_unbalance = True, # this works much better than is_balanced = True
                         max_depth = 8, 
                         importance_type = "gain",
                         early_stopping = 10,
                         drop_rate = .9,
                         min_split_gain = .1)

    clf.fit(X_train, y_train, **fit_params)
    return clf

# %%
# Identify the most important features 
def shapFeatImportance(explainer, df, n):
    shap_values = explainer.shap_values(df)
    
    # identify top features
    feature_vals = np.abs(shap_values).mean(0).mean(0)
    feat_imps = pd.DataFrame(feature_vals, columns = ['importance'])
    feat_imps['feature'] = df.columns
    feat_imps = feat_imps.sort_values(by = "importance", ascending = False).reset_index(drop = True)
    
    return feat_imps, list(feat_imps.feature[:n])

    
# subset to our important columns
def subset2ImpCols(X_train, X_test, imp_cols):
    imp_cols.append("cluster")
    X_train = X_train[imp_cols]
    X_test = X_test[imp_cols]
    return X_train, X_test

# %%
# compute our evaluation metrics 
def evalModel(cluster, clf, X_train, X_test, y_test):
    # number of patients
    train_num_pts = X_train.shape[0]
    val_num_pts = X_test.shape[0]

    # evaluate
    preds = clf.predict(X_test)
    precision = precision_score(y_test, preds)
    recall = recall_score(y_test, preds)
    auc_score = roc_auc_score(y_test, preds)
    f1 = f1_score(y_test, preds)

    # define our 1 row dataframe
    score_df = pd.DataFrame()
    score_df['cluster'] = [cluster]
    score_df['train_num_pts'] = train_num_pts
    score_df['val_num_pts'] = val_num_pts
    score_df['precision'] = precision
    score_df['recall'] = recall
    score_df['f1'] = f1
    score_df['auc'] = auc_score

    return score_df

# %% [markdown]
# ## Run the Model

# %%
# split the data 80/20
def genTrainTests(patient_df, num_clusters, sample_perc = .2, seed = 0):
    train_dfs = []
    test_dfs = []
    
    # run for each cluster - to ensure fairly represented validation sets 
    for c in range(num_clusters):
        sub_df = patient_df.loc[patient_df['cluster'] == c]
        test = sub_df.sample(int(len(sub_df)*sample_perc), replace = False, random_state = seed)
        train = sub_df.loc[~sub_df.subject_id.isin(test.subject_id)]
        
        test_dfs.append(test)
        train_dfs.append(train)
        
    train_out = pd.concat(train_dfs, axis = 0)
    test_out = pd.concat(test_dfs, axis = 0)
    
    return train_out, test_out

# %%
train, test = genTrainTests(patient_df, num_clusters)
display(train.head()) 
display(test.head())
train.shape, test.shape
# Out:
#    subject_id  recreational_drug_use   age  max_heart_rate  min_heart_rate  \
# 0         4.0                    0.0  48.0           111.0            74.0
# 2        78.0                    0.0  49.0            86.0            56.0
# 3       117.0                    0.0  50.0           219.0            56.0
# 6       172.0                    0.0  46.0            84.0            48.0
# 7       186.0                    0.0  76.0           123.0            80.0
#
#    avg_heart_rate  max_resp_rate  min_resp_rate  avg_resp_rate  abdominal  \
# 0       90.354839           32.0           18.0      25.333333   2.021354
# 2       64.681818           24.0           11.0      17.000000   2.021354
# 3       83.629191           34.0            9.0      21.513889   0.000000
# 6       64.041667           21.0           11.0      14.703704   0.000000
# 7       95.087912           28.0           14.0      19.219780   2.021354
#
# ...

# %%
# cross validation
score_dfs = []
feature_imp_dfs = []
drop_cols = ['mortality30', 'time2event', 'subject_id']

for seed in range(5):
    train, test = genTrainTests(patient_df, num_clusters, seed = seed)
    X_train, X_test = train.drop(columns = drop_cols), test.drop(columns = drop_cols)
    y_train, y_test = train.mortality30, test.mortality30
    
    # ML pipeline
    clf = fitClf(X_train, y_train, X_test, y_test)

    # identify important features and subset
    explainer = shap.TreeExplainer(clf)
    feature_imp, imp_cols = shapFeatImportance(explainer, X_train, 50)
    X_train, X_test = subset2ImpCols(X_train, X_test, imp_cols)

    # retrain
    clf = fitClf(X_train, y_train, X_test, y_test)
    
    # store feature importances
    explainer = shap.TreeExplainer(clf)
    feature_imp, imp_cols = shapFeatImportance(explainer, X_train, 50)
    feature_imp['cluster'] = "Total"
    feature_imp['seed'] = seed
    feature_imp_dfs.append(feature_imp)


    # get evaluation rows 
    score_dfs.append(evalModel("Total", clf, X_train, X_test, y_test))
    for c in range(num_clusters):
        X_train_c = X_train.loc[X_train.cluster == c]
        y_train_c = y_train.loc[y_train.index.isin(X_train_c.index)]
        X_test_c = X_test.loc[X_test.cluster == c]
        y_test_c = y_test.loc[y_test.index.isin(X_test_c.index)]
        score_dfs.append(evalModel("Cluster " + str(c), clf, X_train_c, X_test_c, y_test_c))
        
        # store feature importances for clusters
        feature_imp, imp_cols = shapFeatImportance(explainer, X_train_c, 50)
        feature_imp['cluster'] = str(c)
        feature_imp['seed'] = seed
        feature_imp_dfs.append(feature_imp)

        

evaluation = pd.concat(score_dfs, axis = 0)
evaluation
# Out:
# Found `early_stopping` in params. Will use it instead of argument
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [41]	valid's auc: 0.921473	valid's binary_logloss: 0.324561
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray
# Found `early_stopping` in params. Will use it instead of argument
# Training until validation scores don't improve for 10 rounds
# Early stopping, best iteration is:
# [56]	valid's auc: 0.920101	valid's binary_logloss: 0.322846
# Setting feature_perturbation = "tree_path_dependent" because no background data was given.
# LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray
# LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray
# ...

# %%
# now we average our entire validation set 
evaluation_final = evaluation.groupby(['cluster'], as_index = False).mean()
evaluation_final
# Out:
#      cluster  train_num_pts  val_num_pts  precision    recall        f1  \
# 0  Cluster 0           1110          277   0.758059  0.746590  0.750301
# 1  Cluster 1           1186          296   0.711673  0.796279  0.749801
# 2      Total           2296          573   0.733722  0.769453  0.750764
#
#         auc
# 0  0.822771
# 1  0.848078
# 2  0.834400

# %%
# get our feature importances across all CVs
feature_imps = pd.concat(feature_imp_dfs, axis = 0)
feature_imps = feature_imps.groupby(["feature", "cluster"], as_index = False).sum()\
                            .drop(columns = "seed")\
                            .sort_values(by = ['cluster', 'importance'], ascending = False)
feature_imps
# Out:
#              feature cluster  importance
# 29           avg_inr   Total    1.719952
# 5                age   Total    1.122061
# 149   min_heart_rate   Total    1.098554
# 44     avg_potassium   Total    0.968676
# 62   braden_mobility   Total    0.943887
# ..               ...     ...         ...
# 174    pain_location       0    0.066318
# 93         max_alkph       0    0.062663
# 177     pain_present       0    0.058061
# 63   braden_moisture       0    0.056258
# 123          max_ptt       0    0.025785
#
# [183 rows x 3 columns]

# %%
temp_imps = feature_imps.loc[feature_imps.cluster == "Total",:].sort_values(by = ["cluster", "importance"], ascending = False)
plt.barh(temp_imps.feature[:20],list(temp_imps.loc[:, "importance"][:20]))
# Out:
# <BarContainer object of 20 artists>

# %%
temp_imps = feature_imps.loc[feature_imps.cluster == "0",:].sort_values(by = ["cluster", "importance"], ascending = False)
plt.barh(temp_imps.feature[:20],list(temp_imps.loc[:, "importance"][:20]))
# Out:
# <BarContainer object of 20 artists>

# %%
temp_imps = feature_imps.loc[feature_imps.cluster == "1",:].sort_values(by = ["cluster", "importance"], ascending = False)
plt.barh(temp_imps.feature[:20],list(temp_imps.loc[:, "importance"][:20]))
# Out:
# <BarContainer object of 20 artists>

# %%
evaluation_final.to_csv(output_dir + "Summary Table.csv", index = False)
feature_imps.to_csv(output_dir + "Feature Importances.csv", index = False)

# %% [markdown]
# Export Model and relevant information

# %%
import pickle

# export model
with open("../shiny/data/30DayMortality/mortalityModel.pkl", "wb") as f:
    pickle.dump(clf, f)

# export shap explainer 
with open("../shiny/data/30DayMortality/shapExplainer.pkl", "wb") as f:
    pickle.dump(explainer, f)

# %%
# extract final columns
X_train.columns
# Out:
# Index(['avg_inr', 'age', 'min_heart_rate', 'max_creatinine', 'avg_potassium',
#        'braden_mobility', 'cough_reflex', 'avg_creatinine', 'min_lactate',
#        'min_pt', 'avg_heart_rate', 'abdominal_assessment', 'min_bilirubin',
#        'min_wgt', 'avg_phosphate', 'min_ast', 'diet_type', 'braden_nutrition',
#        'avg_albumin', 'max_lactate', 'avg_lactate', 'min_ptt',
#        'min_creatinine', 'incisional', 'max_alt', 'max_heart_rate',
#        'avg_resp_rate', 'avg_bilirubin', 'max_resp_rate', 'avg_sodium',
#        'avg_alt', 'min_alkph', 'max_bilirubin', 'loss_perc', 'avg_alkph',
#        'max_platelet', 'gag_reflex', 'min_ld', 'max_wgt', 'avg_platelet',
#        'avg_ld', 'max_albumin', 'max_ld', 'max_pt', 'min_albumin',
#        'braden_moisture', 'wgt_change', 'min_resp_rate', 'avg_pt', 'avg_ast',
#        'cluster'],
#       dtype='object')
